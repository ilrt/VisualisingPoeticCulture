# %% [markdown]
# Load all the sheets as a single data frame:

# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd
import visualising_poetry as vp
vp.setup_if_needed()
df = vp.pickle_as_single_data_frame()

# %% [markdown]
# Total number of poems per publications

# %%
total = df.groupby('publication title')['first line'].size()
print(total)
total.plot(kind='bar', title="Total poems discovered by publication", figsize=(10,10), yticks=np.arange(0,3000,500))
plot.xlabel("Publications")
plot.ylabel("No. of poems")
plot.show()
# Out:
# publication title
# British Magazine                             692
# Common Sense                                  40
# Craftsman                                     18
# Daily Gazetteer                              129
# Dublin Journal                               171
# General Evening Post                         128
# Gentlemans                                  1436
# Ladies Magazine                              733
# London Daily Post and General Advertiser      40
# London Evening Post                          621
# London Magazine                             3238
# London Morning Advertiser                     11
# Magazine of Magazines (London)               148
# Museum                                       147
# Newcastle General Magazine                  1291
# Scots                                       1085
# St James Evening Post                         14
# Universal                                    209
# Universal Spectator                          364
# Westminster Journal                           35
# Name: first line, dtype: int64
